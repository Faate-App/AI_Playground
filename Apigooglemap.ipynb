# %%
import requests
import time
def trouver_lieux(lat, lng, type_lieu, api_key):
    """
    Trouve des lieux d'un type spécifique dans une zone donnée en utilisant l'API Google Places.

    Args:
    - lat (float): Latitude du centre de la zone de recherche.
    - lng (float): Longitude du centre de la zone de recherche.
    - type_lieu (str): Type de lieu à rechercher (par exemple, "bar" ou "night_club").
    - api_key (str): Clé API pour Google Places.

    Returns:
    - list: Liste des lieux trouvés.
    """
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        'location': f'{lat},{lng}',
        'radius': 2000,  # Rayon de recherche en mètres
        'type': type_lieu,
        'key': api_key
    }
    reponse = requests.get(url, params=params)
    resultats = reponse.json()
    print(resultats)
    if resultats.get("status") == "OK":
        lieux = resultats.get("results")
        noms_lieux = [lieu.get("name") for lieu in lieux]
        return noms_lieux
    else:
        return []

# %%
api_key = "AIzaSyAuz6HCelEoLHELYGFA6HeNC9CAMB3XKmE"
latitude =  48.80317135# Latitude de Bougival
longitude = 2.26646045  # Longitude de Bougival

bars = trouver_lieux(latitude, longitude, "bar", api_key)
time.sleep(0.0001)
boites_de_nuit = trouver_lieux(latitude, longitude, "night_club", api_key)

print("Bars trouvés:", bars)
print("Boîtes de nuit trouvées:", boites_de_nuit)
# Out:
# {'html_attributions': [], 'next_page_token': 'AWU5eFh00ceKcOf6Rscz-4DEcALkKsJ1lXdGMbyQlx7VG7dZj_hYjRSSTzqXE2XwuZjN8FKrm3AbXg6dBge3BBJeW0I0XHJJu4JJEJRLEvRcyLeSClkg7W-KdkE2c8zNP1C4cQBaZl3XpsL9fxboAg2iCCITM2l_Cvn0haNOB_pikzRlU975OcaphVwFm7Jz7xWEOmSkth4K4Ro9KegRsNjvSPtEncAqr_Nmi-lmqAxZQfayV3JhFn1E0i0Bl-BkFVN9cxXASKWfjfe7_fZZyBkfj5MTo1J84N_J_DKT9kUNZ_UfjEKAKqj0OKixOuN2HKjiuM-ctHm1LJ4RHYlQeqFUPG_481zYiedPKc-djiQz1lhAY1XkJ6ioqzbSn_uyzLmgJGcqumyA7nCtKypY-Rc45fEzrRYNOwJ7r_Gbo6tOOkGvQA5YKWM', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8032602, 'lng': 2.2895199}, 'viewport': {'northeast': {'lat': 48.8046007802915, 'lng': 2.290939380291502}, 'southwest': {'lat': 48.8019028197085, 'lng': 2.288241419708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'name': 'Le Barbezingue', 'opening_hours': {'open_now': False}, 'photos': [{'height': 500, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103573238932542688778">Le Barbezingue</a>'], 'photo_reference': 'AWU5eFjQN_J-Hk4PgRVQk66Rk0eD0VcJWlYXBaXFTZfCgHo2bzqRnaMQcTCsHIZTwwSVlVaMmMxUrftwGor1vpWtruALmPLmmOBUPiLnt0RkTHbJoSY-31jgBNo-vBuHzusc6-jTga34hZxhjN_CXuGeSZMnMfK1SU79sHeLGtMh9N4njNjP', 'width': 333}], 'place_id': 'ChIJrfH-X5Fw5kcRvLfku8-iYDI', 'plus_code': {'compound_code': 'R73Q+8R Châtillon, France', 'global_code': '8FW4R73Q+8R'}, 'price_level': 2, 'rating': 4.3, 'reference': 'ChIJrfH-X5Fw5kcRvLfku8-iYDI', 'scope': 'GOOGLE', 'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment
 'place_id': 'ChIJ98hA_4Rx5kcRknaWZ3g6w5A', 'plus_code': {'compound_code': 'Q7RM+9P Fontenay-aux-Roses, France', 'global_code': '8FW4Q7RM+9P'}, 'rating': 5, 'reference': 'ChIJ98hA_4Rx5kcRknaWZ3g6w5A', 'scope': 'GOOGLE', 'types': ['night_club', 'point_of_interest', 'establishment'], 'user_ratings_total': 13, 'vicinity': "3 Rue d'Estienne d'Orves, Fontenay-aux-Roses"}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8194679, 'lng': 2.2560964}, 'viewport': {'northeast': {'lat': 48.8208594802915, 'lng': 2.257388780291502}, 'southwest': {'lat': 48.8181615197085, 'lng': 2.254690819708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet', 'name': "Le Liv'", 'opening_hours': {'open_now': True}, 'photos': [{'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115806283137412344830">Pierre Driot</a>'], 'photo_reference': 'AWU5eFgF2jqsg_8_ILojbuy1QwdnV0NcuUuOROn2wyLn-vVzv8kuzn7AkM322ngdoTINjoQraJAFckFz6LuoxFpj2RHEV_eezZ2Sx9ss90XNM7E-NnJxviBDii6QebdXVKNOekGHNPQSiAw-Ibm5uRPowbbfJJvq3jn-q1DdJ7SQcgLhpsc2', 'width': 3024}], 'place_id': 'ChIJP8pSOIp65kcREZpMtH2hbvw', 'plus_code': {'compound_code': 'R794+QC Issy-les-Moulineaux, France', 'global_code': '8FW4R794+QC'}, 'rating': 4.2, 'reference': 'ChIJP8pSOIp65kcREZpMtH2hbvw', 'scope': 'GOOGLE', 'types': ['night_club', 'bar', 'point_of_interest', 'establishment'], 'user_ratings_total': 86, 'vicinity': '109 Avenue de Verdun, Issy-les-Moulineaux'}], 'status': 'OK'}
# Bars trouvés: ['Le Barbezingue', 'Libre Service Clamart', 'Nicolas Clamart', 'Aux 3 Garçons', 'Le Victor Hugo', 'Tabac Du Clos', 'Yokohama', 'Escampette - Bistrot à vins', 'Le Commerce Brasserie et Restaurant Thaïlandais', 'Le New Maryland', 'Sayori Sushi', 'Wheat in the grass', 'Le Monde En Marche', "Brasserie de l'Hôtel de Ville", 'Le Percy', 'Big-Boss', 'Tabac Brasseerie Salon De The', 'Le Living Bar Restaurant', 'Wang Jacques', 'Le Narval']
# Boîtes de nuit trouvées: ['Club Gravier', "Le Liv'"]

# %%
import pgeocode
import random  
nomi = pgeocode.Nominatim('fr')
data = nomi.query_location("Boulogne-Billancourt",top_k=1)

# Extraction des coordonnées de base
lat_base = data['latitude'].values[0]  # Pour obtenir la première valeur de la Series latitude
lng_base = data['longitude'].values[0]  # Pour obtenir la première valeur de la Series longitude
print(f"Latitude de base: {lat_base}")  
print(f"Longitude de base: {lng_base}")
# Ajout d'une petite variation aléatoire pour rendre les coordonnées uniques
lat = lat_base + random.uniform(-0.0005, 0.0005)
lng = lng_base + random.uniform(-0.0005, 0.0005)
lat = round(lat, 7)
lng = round(lng, 7)
# Out:
# Latitude de base: 48.8354
# Longitude de base: 2.2413
# Latitude unique: 48.8351452
# Longitude unique: 2.240961
